# %%
# Got this running with the following environment:

# conda create -n repair-seq python=3.8
# conda list
# appnope                   0.1.3              pyhd8ed1ab_0    conda-forge
# asttokens                 2.1.0              pyhd8ed1ab_0    conda-forge
# attrs                     22.2.0                   pypi_0    pypi
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backports                 1.0                        py_2    conda-forge
# backports.functools_lru_cache 1.6.4              pyhd8ed1ab_0    conda-forge
# beautifulsoup4            4.11.2                   pypi_0    pypi
# biopython                 1.81                     pypi_0    pypi
# bleach                    6.0.0                    pypi_0    pypi
# bokeh                     3.0.3                    pypi_0    pypi
# bzip2                     1.0.8                h0d85af4_4    conda-forge
# ca-certificates           2022.9.24            h033912b_0    conda-forge
# contourpy                 1.0.7                    pypi_0    pypi
# cycler                    0.11.0                   pypi_0    pypi
# cython                    0.29.33                  pypi_0    pypi
# debugpy                   1.6.3            py38h4cd09af_1    conda-forge
# decorator                 5.1.1              pyhd8ed1ab_0    conda-forge
# defusedxml                0.7.1                    pypi_0    pypi
# entrypoints               0.4                pyhd8ed1ab_0    conda-forge
# executing                 1.2.0              pyhd8ed1ab_0    conda-forge
# fastjsonschema            2.16.3                   pypi_0    pypi
# fonttools                 4.39.0                   pypi_0    pypi
# h5py                      3.8.0                    pypi_0    pypi
# hdbscan                   0.8.26                   pypi_0    pypi
# hits                      0.4.0                    pypi_0    pypi
# importlib-metadata        6.0.0                    pypi_0    pypi
# importlib-resources       5.12.0                   pypi_0    pypi
# ipykernel                 6.17.1             pyh736e0ef_0    conda-forge
# ipython                   8.6.0              pyhd1c38e8_1    conda-forge
# ipywidgets                8.0.4                    pypi_0    pypi
# jedi                      0.18.1             pyhd8ed1ab_2    conda-forge
# jinja2                    3.1.2                    pypi_0    pypi
# joblib                    1.1.0                    pypi_0    pypi
# jsonschema                4.17.3                   pypi_0    pypi
# jupyter-core              5.2.0                    pypi_0    pypi
# jupyter_client            7.4.7              pyhd8ed1ab_0    conda-forge
# jupyterlab-pygments       0.2.2                    pypi_0    pypi
# jupyterlab-widgets        3.0.5                    pypi_0    pypi
# kiwisolver                1.4.4                    pypi_0    pypi
# knock-knock               0.4.2                    pypi_0    pypi
# libcxx                    14.0.6               hccf4f1f_0    conda-forge
# libffi                    3.4.2                h0d85af4_5    conda-forge
# libsodium                 1.0.18               hbcb3906_1    conda-forge
# libsqlite                 3.40.0               ha978bb4_0    conda-forge
# libzlib                   1.2.13               hfd90126_4    conda-forge
# llvmlite                  0.34.0                   pypi_0    pypi
# markupsafe                2.1.2                    pypi_0    pypi
# matplotlib                3.7.1                    pypi_0    pypi
# matplotlib-inline         0.1.6              pyhd8ed1ab_0    conda-forge
# mistune                   2.0.5                    pypi_0    pypi
# nbclient                  0.7.2                    pypi_0    pypi
# nbconvert                 7.2.9                    pypi_0    pypi
# nbformat                  5.7.3                    pypi_0    pypi
# ncurses                   6.3                  h96cf925_1    conda-forge
# nest-asyncio              1.5.6              pyhd8ed1ab_0    conda-forge
# numba                     0.51.2                   pypi_0    pypi
# numpy                     1.23.0                   pypi_0    pypi
# openssl                   3.0.7                hfd90126_0    conda-forge
# packaging                 21.3               pyhd8ed1ab_0    conda-forge
# pandas                    1.5.3                    pypi_0    pypi
# pandocfilters             1.5.0                    pypi_0    pypi
# parso                     0.8.3              pyhd8ed1ab_0    conda-forge
# patsy                     0.5.3                    pypi_0    pypi
# pexpect                   4.8.0              pyh1a96a4e_2    conda-forge
# pickleshare               0.7.5                   py_1003    conda-forge
# pillow                    9.4.0                    pypi_0    pypi
# pip                       22.3.1             pyhd8ed1ab_0    conda-forge
# pkgutil-resolve-name      1.3.10                   pypi_0    pypi
# platformdirs              2.5.2              pyhd8ed1ab_1    conda-forge
# prompt-toolkit            3.0.32             pyha770c72_0    conda-forge
# psutil                    5.9.4            py38hef030d1_0    conda-forge
# ptyprocess                0.7.0              pyhd3deb0d_0    conda-forge
# pure_eval                 0.2.2              pyhd8ed1ab_0    conda-forge
# pygments                  2.13.0             pyhd8ed1ab_0    conda-forge
# pyparsing                 3.0.9              pyhd8ed1ab_0    conda-forge
# pyrsistent                0.19.3                   pypi_0    pypi
# pysam                     0.20.0                   pypi_0    pypi
# python                    3.8.13          h66c20e1_0_cpython    conda-forge
# python-dateutil           2.8.2              pyhd8ed1ab_0    conda-forge
# python_abi                3.8                      2_cp38    conda-forge
# pytz                      2022.7.1                 pypi_0    pypi
# pyyaml                    6.0                      pypi_0    pypi
# pyzmq                     24.0.1           py38h0b711fd_0    conda-forge
# readline                  8.1.2                h3899abd_0    conda-forge
# repair-seq                1.0.3                    pypi_0    pypi
# scikit-learn              1.2.2                    pypi_0    pypi
# scipy                     1.10.1                   pypi_0    pypi
# seaborn                   0.12.2                   pypi_0    pypi
# setuptools                65.5.1             pyhd8ed1ab_0    conda-forge
# six                       1.16.0             pyh6c4a22f_0    conda-forge
# soupsieve                 2.4                      pypi_0    pypi
# sqlite                    3.40.0               h9ae0607_0    conda-forge
# stack_data                0.6.1              pyhd8ed1ab_0    conda-forge
# statsmodels               0.13.5                   pypi_0    pypi
# threadpoolctl             3.1.0                    pypi_0    pypi
# tinycss2                  1.2.1                    pypi_0    pypi
# tk                        8.6.12               h5dbffcc_0    conda-forge
# tornado                   6.2              py38hef030d1_1    conda-forge
# tqdm                      4.65.0                   pypi_0    pypi
# traitlets                 5.5.0              pyhd8ed1ab_0    conda-forge
# umap-learn                0.4.6                    pypi_0    pypi
# wcwidth                   0.2.5              pyh9f0ad1d_2    conda-forge
# webencodings              0.5.1                    pypi_0    pypi
# wheel                     0.38.4             pyhd8ed1ab_0    conda-forge
# widgetsnbextension        4.0.5                    pypi_0    pypi
# xyzservices               2023.2.0                 pypi_0    pypi
# xz                        5.2.6                h775f41a_0    conda-forge
# zeromq                    4.3.4                he49afe7_1    conda-forge
# zipp                      3.15.0                   pypi_0    pypi

# %%
from collections import defaultdict, Counter
from pathlib import Path
import warnings
import numpy as np
import repair_seq as rs
import pandas as pd
import umap
import pickle as pkl

import matplotlib
import seaborn as sns
import sklearn
from repair_seq.cluster import HDBSCAN
import matplotlib.pyplot as plt
from repair_seq import visualize

# joblib-1.1.0
# numpy v1.23.0

# %%
with warnings.catch_warnings():
    # Suppress a warning about TBB_INTERFACE_VERSION
    warnings.simplefilter('ignore')
    base_dir = Path('/Users/colm/repos/MUSICian/data/external/Hussmann2021/Repair-seq_DSB_data').resolve()
    pools = rs.pooled_screen.get_all_pools(base_dir)

    pool_names = [
        'K562_SpCas9_target-1_none_AC001_1',
        'K562_SpCas9_target-1_none_AC001_2',
        'K562_SpCas9_target-4_none_AC001_1',
        'K562_SpCas9_target-4_none_AC001_2',
        'K562_SpCas9_target-3_none_AC001_1',
        'K562_SpCas9_target-3_none_AC001_2',
        'K562_SpCas9_target-2_none_AC001_1',
    ]

# %%
pool_specific_outcomes = {}
for name in pool_names:
    outcomes = pools[name].outcomes_above_simple_threshold(frequency_threshold=2e-3,
                    use_high_frequency_counts=True)
    pool_specific_outcomes[pools[name].short_name] = outcomes

# %%
guide_to_gene = {}

for name in pool_names:
    guide_to_gene.update(pools[name].variable_guide_library.guide_to_gene)

# %%
active_guide_lists = defaultdict(list)

for name in pool_names:
    for i, guide in enumerate(pools[name].canonical_active_guides(use_high_frequency_counts=True)):
        active_guide_lists[guide].append((pools[name].short_name, i))

# Include guides that were active in at least two screens.
# Only include up to 3 guides per gene, prioritized by average activity rank.

gene_guides = defaultdict(list)

for guide, active_pns in active_guide_lists.items():
    if len(active_pns) >= min(len(pools), 2):
        average_rank = np.mean([rank for pn, rank in active_pns])
        gene_guides[guide_to_gene[guide]].append((average_rank, guide))
        
filtered_guides = []
for gene, guides in gene_guides.items():
    guides = [g for r, g in sorted(guides)]
    filtered_guides.extend(guides[:3])

guides = filtered_guides

# %%
all_fcs = {}

for name in pool_names:
    fcs = pools[name].high_frequency_log2_fold_changes
    all_fcs[pools[name].short_name] = fcs.loc[pool_specific_outcomes[pools[name].short_name], guides]
    
all_fcs = pd.concat(all_fcs)

all_fcs.index.names = ['pool_name'] + all_fcs.index.names[1:]
all_fcs.head()
# Out:
# variable_guide                                                                                   POLL_2  \
# pool_name                         category          subcategory details
# K562_SpCas9_target-1_none_AC001_1 insertion         near cut    I:{252|253|254|255},{A|A|A|A} -2.258018
#                                   deletion          near cut    D:{253|254|255},1             -0.580244
#                                                                 D:{251|252|253},4             -0.106858
#                                                                 D:{251|252},2                  0.551177
#                                   genomic insertion hg19        >75 nts                       -0.490476
#
# variable_guide                                                                                  POLL_10  \
# pool_name                         category          subcategory details
# ...

# %%
log2_fold_changes = all_fcs

# %%
def assign_palette(results, axis):
    if 'cluster_assignments' in results:
        num_clusters = len(set(results['cluster_assignments']))

        if axis == 'guides':
            palette = sns.husl_palette(num_clusters)
        elif axis == 'outcomes':
            palette = sns.color_palette('muted', n_colors=num_clusters)
        else:
            raise ValueError(axis)

        results['palette'] = palette
        grey = matplotlib.colors.to_rgb('silver')
        cluster_colors = {i: palette[i] for i in range(num_clusters)}
        results['cluster_colors'] = cluster_colors

        results['colors'] = {key: cluster_colors.get(i, grey) for key, i in zip(results['clustered_order'], results['cluster_assignments'])}

results = HDBSCAN(log2_fold_changes, 'guides')
assign_palette(results, 'guides')
guide_clustering = results

# %%
# taken from cluster.py from repair-seq
# options.setdefault('guides_seed', 0)
# options.setdefault('outcomes_seed', 0)
# options.setdefault('outcomes_min_dist', 0.2)
# options.setdefault('guides_min_dist', 0.2)
# options['guides_kwargs'].setdefault('metric', 'cosine')
# options['outcomes_selection_kwargs'].setdefault('threshold', 2e-3)


reducer = umap.UMAP(random_state=0,
                    metric='cosine',
                    n_neighbors=10,
                    min_dist=0.2,
                    )
embedding = reducer.fit_transform(log2_fold_changes.T)
embedding = pd.DataFrame(embedding,
                columns=['x', 'y'],
                index=log2_fold_changes.columns,
            )
embedding['color'] = pd.Series(guide_clustering['colors'])
embedding['gene'] = [guide_to_gene[guide] for guide in embedding.index]
embedding['cluster_assignments'] = pd.Series(guide_clustering['cluster_assignments'], index=guide_clustering['clustered_order'])

# %%
def plot_guide_embedding(
                        guide_embedding,
                        guide_library,
                        figsize=(12, 12),
                        color_by='cluster',
                        label_genes=True,
                        label_alpha=1,
                        legend_location='lower right',
                        label_size=8,
                        marker_size=None,
                        circle_edge_width=0,
                        gene_line_width=1,
                    ):
        fig, ax = plt.subplots(figsize=figsize)

        data = guide_embedding.copy()

        if color_by == 'cluster':
            # sort so that guides assigned to clusters are drawn on top
            data['sort_by'] = data['cluster_assignments']
            data = data.sort_values(by='sort_by')
        elif color_by == 'gamma':
            min_gamma = -0.3

            values = guide_library.guides_df['gamma'].loc[data.index]
            cmap = visualize.gamma_cmap

            norm = matplotlib.colors.Normalize(vmin=min_gamma, vmax=0)
            sm = matplotlib.cm.ScalarMappable(norm=norm, cmap=cmap)

            colors = [tuple(row) for row in sm.to_rgba(values)]
            data['color'] = colors
            # sort so that strongest (negative) gammas are drawn on top
            data['sort_by'] = -values
            data = data.sort_values(by='sort_by')

            ax_p = ax.get_position()

            if legend_location == 'lower right':
                x0 = ax_p.x0 + 0.65 * ax_p.width
                y0 = ax_p.y0 + 0.25 * ax_p.height
            elif legend_location == 'upper right':
                x0 = ax_p.x0 + 0.70 * ax_p.width
                y0 = ax_p.y0 + 0.95 * ax_p.height
            else:
                raise NotImplementedError

            cax = fig.add_axes([x0,
                                y0,
                                0.25 * ax_p.width,
                                0.03 * ax_p.height,
                                ])

            colorbar = plt.colorbar(mappable=sm, cax=cax, orientation='horizontal')
            ticks = [min_gamma, 0]
            tick_labels = [str(t) for t in ticks]
            tick_labels[0] = '$\leq$' + tick_labels[0]
            colorbar.set_ticks(ticks)
            colorbar.set_ticklabels(tick_labels)
            colorbar.outline.set_alpha(0)
            colorbar.set_label(f'gamma', size=6)
            cax.tick_params(labelsize=6, width=0.5)

        elif color_by in guide_library.cell_cycle_log2_fold_changes.index:
            phase = color_by

            values = guide_library.cell_cycle_log2_fold_changes.loc[phase, data.index]
            cmap = visualize.cell_cycle_cmap

            norm = matplotlib.colors.Normalize(vmin=-1, vmax=1)
            sm = matplotlib.cm.ScalarMappable(norm=norm, cmap=cmap)

            colors = [tuple(row) for row in sm.to_rgba(values)]

            data['color'] = colors

            # sort by absolute value of fold changes so that most extreme
            # points are drawn on top
            data['sort_by'] = np.abs(values)
            data = data.sort_values(by='sort_by')

            ax_p = ax.get_position()

            if legend_location == 'lower right':
                x0 = ax_p.x0 + 0.65 * ax_p.width
                y0 = ax_p.y0 + 0.25 * ax_p.height
            elif legend_location == 'upper right':
                x0 = ax_p.x0 + 0.70 * ax_p.width
                y0 = ax_p.y0 + 0.95 * ax_p.height
            else:
                raise NotImplementedError

            cax = fig.add_axes([x0,
                                y0,
                                0.25 * ax_p.width,
                                0.03 * ax_p.height,
                                ])

            colorbar = plt.colorbar(mappable=sm, cax=cax, orientation='horizontal')
            ticks = [-1, 0, 1]
            tick_labels = [str(t) for t in ticks]
            tick_labels[0] = '$\leq$' + tick_labels[0]
            tick_labels[-1] = '$\geq$' + tick_labels[-1]
            colorbar.set_ticks(ticks)
            colorbar.set_ticklabels(tick_labels)
            colorbar.outline.set_alpha(0)
            colorbar.set_label(f'log$_2$ fold change\nin {phase} occupancy', size=6)
            cax.tick_params(labelsize=6, width=0.5)

        if marker_size is None:
            marker_size = figsize[0] * 100 / 12

        ax.scatter(x='x',
                   y='y',
                   color='color',
                   data=data,
                   s=marker_size,
                   alpha=0.8,
                   edgecolors='black',
                   linewidths=(circle_edge_width,),
                   #marker='s',
                  )

        if label_genes == 'all':
            for guide, row in guide_embedding.iterrows():
                ax.annotate(row['gene'],
                            xy=(row['x'], row['y']),
                            xytext=(2, 0),
                            textcoords='offset points',
                            ha='left',
                            va='center',
                            size=label_size,
                            alpha=label_alpha,
                           )

        elif label_genes:
            for gene, rows in guide_embedding.groupby('gene', sort=False):
                n_rows, _ = rows.shape
                for first_index in range(n_rows):
                    first_row = rows.iloc[first_index]
                    for second_index in range(first_index + 1, n_rows):
                        second_row = rows.iloc[second_index]
                        xs = [first_row['x'], second_row['x']]
                        ys = [first_row['y'], second_row['y']]
                        if gene_line_width > 0:
                            ax.plot(xs, ys, linewidth=gene_line_width, color='black', alpha=0.1)

                centroid = (rows['x'].mean(), rows['y'].mean())

                if n_rows == 1:
                    num_guides_string = ''
                else:
                    num_guides_string = f' ({len(rows)})'
                    
                ax.annotate(f'{gene}{num_guides_string}',
                            xy=centroid,
                            xytext=(0, 0),
                            textcoords='offset points',
                            ha='center',
                            va='center',
                            size=label_size,
                            alpha=label_alpha,
                        )

        x_min = data['x'].min()
        x_max = data['x'].max()
        x_range = x_max - x_min
        buffer = 0.05 * x_range
        ax.set_xlim(x_min - buffer, x_max + buffer)

        y_min = data['y'].min()
        y_max = data['y'].max()
        y_range = y_max - y_min
        buffer = 0.05 * y_range
        ax.set_ylim(y_min - buffer, y_max + buffer)

        ax.set_xticks([])
        ax.set_yticks([])
        plt.setp(fig.axes[0].spines.values(), alpha=0.5)

        return fig, data

# %%
guide_library = pools[pool_names[0]].variable_guide_library

fig, data = plot_guide_embedding(
    embedding,
    guide_library,
    color_by='cluster',
    label_genes='all',
    figsize=(4, 4),
    label_size=3,
    label_alpha=0.5,
    marker_size=10,
    gene_line_width=0,
    )

fig.axes[0].invert_xaxis()
plt.savefig("artifacts/adamson_recreation.pdf")

# %%
data
# Out:
#                        x         y  \
# variable_guide
# POLE_1          4.085709  2.640904
# RAD51_3         3.679185  4.184721
# MCM2_1          3.186232  3.499613
# MCM2_2          2.916432  3.064387
# PRPF19_3        9.336550  6.271903
# ...                  ...       ...
# RAD17_3         0.150938  6.080622
# RAD17_1         0.503307  6.039637
# POLQ_2          0.314580  6.643331
# POLQ_3          0.203648  6.591086
# POLQ_1          0.503999  6.576087
#
#                                                             color    gene  \
# variable_guide
# POLE_1          (0.7529411764705882, 0.7529411764705882, 0.752...    POLE
# RAD51_3         (0.7529411764705882, 0.7529411764705882, 0.752...   RAD51
# MCM2_1          (0.7529411764705882, 0.7529411764705882, 0.752...    MCM2
# MCM2_2          (0.7529411764705882, 0.7529411764705882, 0.752...    MCM2
# PRPF19_3        (0.7529411764705882, 0.7529411764705882, 0.752...  PRPF19
# ...

# %%
pkl.dump(data, open("artifacts/adamson_cluster_assignments.pkl", "wb"))

# %%
# !cp artifacts/adamson_cluster_assignments.pkl $HOME/repos/dsb-gene-function-prediction/data/external/Adamson2021
# !ls -l $HOME/repos/dsb-gene-function-prediction/data/external/Adamson2021
# Out:
# total 440
# -rw-r--r--@ 1 colm  staff   12106 Jul  7 15:20 1-s2.0-S0092867421011764-mmc1.xlsx
# -rw-r--r--@ 1 colm  staff  175655 Jul  7 15:20 1-s2.0-S0092867421011764-mmc3.xlsx
# -rw-r--r--@ 1 colm  staff   24435 Jul  7 15:20 1-s2.0-S0092867421011764-mmc4.xlsx
# -rw-r--r--  1 colm  staff   10466 Aug  7 15:26 adamson_cluster_assignments.pkl

# %%
targets = {
    "target-1": ["K562_SpCas9_target-1_none_AC001_1", "K562_SpCas9_target-1_none_AC001_2"],
    "target-2": ["K562_SpCas9_target-2_none_AC001_1"],
    "target-3": ["K562_SpCas9_target-3_none_AC001_1", "K562_SpCas9_target-3_none_AC001_2"],
    "target-4": ["K562_SpCas9_target-4_none_AC001_1", "K562_SpCas9_target-4_none_AC001_2"]
}

# %%
for name in list(targets.keys()):
    reducer = umap.UMAP(random_state=0,
                    metric='cosine',
                    n_neighbors=10,
                    min_dist=0.2,
                    )
    embedding = reducer.fit_transform(log2_fold_changes.T[targets[name]])
    embedding = pd.DataFrame(embedding,
                    columns=['x', 'y'],
                    index=log2_fold_changes.columns,
                )
    embedding['color'] = pd.Series(guide_clustering['colors'])
    embedding['gene'] = [guide_to_gene[guide] for guide in embedding.index]
    embedding['cluster_assignments'] = pd.Series(guide_clustering['cluster_assignments'], index=guide_clustering['clustered_order'])

    guide_library = pools[pool_names[0]].variable_guide_library

    fig, data = plot_guide_embedding(
        embedding,
        guide_library,
        color_by='cluster',
        label_genes='all',
        figsize=(4, 4),
        label_size=3,
        label_alpha=0.5,
        marker_size=10,
        gene_line_width=0,
        )

    fig.axes[0].invert_xaxis()
    plt.title(name)
    plt.tight_layout()
    plt.savefig("artifacts/adamson_recreation_{}.pdf".format(name))
