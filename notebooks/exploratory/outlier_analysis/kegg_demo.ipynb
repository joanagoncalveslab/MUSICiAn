# %%
# OPTIONAL: Load the "autoreload" eX_orig[alias]tension so that code can change
# %load_ext autoreload

# OPTIONAL: always reload modules so that as you change code in src, it gets loaded
# %autoreload 2

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Import Biopython modules to interact with KEGG
from Bio import SeqIO
from Bio.KEGG import REST
from Bio.KEGG.KGML import KGML_parser
from Bio.Graphics.KGML_vis import KGMLCanvas

import pandas as pd
import io
import numpy as np

# %%
mouse_pathways = REST.kegg_list("pathway", "mmu").read()
mouse_pathways.split("\n")[0:5]
# Out:
# ['mmu01100\tMetabolic pathways - Mus musculus (house mouse)',
#  'mmu01200\tCarbon metabolism - Mus musculus (house mouse)',
#  'mmu01210\t2-Oxocarboxylic acid metabolism - Mus musculus (house mouse)',
#  'mmu01212\tFatty acid metabolism - Mus musculus (house mouse)',
#  'mmu01230\tBiosynthesis of amino acids - Mus musculus (house mouse)']

# %%
mouse_pathways.split("\n")
# Out:
# ['mmu01100\tMetabolic pathways - Mus musculus (house mouse)',
#  'mmu01200\tCarbon metabolism - Mus musculus (house mouse)',
#  'mmu01210\t2-Oxocarboxylic acid metabolism - Mus musculus (house mouse)',
#  'mmu01212\tFatty acid metabolism - Mus musculus (house mouse)',
#  'mmu01230\tBiosynthesis of amino acids - Mus musculus (house mouse)',
#  'mmu01232\tNucleotide metabolism - Mus musculus (house mouse)',
#  'mmu01250\tBiosynthesis of nucleotide sugars - Mus musculus (house mouse)',
#  'mmu01240\tBiosynthesis of cofactors - Mus musculus (house mouse)',
#  'mmu00010\tGlycolysis / Gluconeogenesis - Mus musculus (house mouse)',
#  'mmu00020\tCitrate cycle (TCA cycle) - Mus musculus (house mouse)',
#  'mmu00030\tPentose phosphate pathway - Mus musculus (house mouse)',
#  'mmu00040\tPentose and glucuronate interconversions - Mus musculus (house mouse)',
#  'mmu00051\tFructose and mannose metabolism - Mus musculus (house mouse)',
#  'mmu00052\tGalactose metabolism - Mus musculus (house mouse)',
#  'mmu00053\tAscorbate and aldarate metabolism - Mus musculus (house mouse)',
#  'mmu00500\tStarch and sucrose metabolism - Mus musculus (house mouse)',
#  'mmu00520\tAmino sugar and nucleotide sugar metabolism - Mus musculus (house mouse)',
#  'mmu00620\tPyruvate metabolism - Mus musculus (house mouse)',
#  'mmu00630\tGlyoxylate and dicarboxylate metabolism - Mus musculus (house mouse)',
#  'mmu00640\tPropanoate metabolism - Mus musculus (house mouse)',
#  'mmu00650\tButanoate metabolism - Mus musculus (house mouse)',
#  'mmu00562\tInositol phosphate metabolism - Mus musculus (house mouse)',
#  'mmu00190\tOxidative phosphorylation - Mus musculus (house mouse)',
#  'mmu00910\tNitrogen metabolism - Mus musculus (house mouse)',
#  'mmu00920\tSulfur metabolism - Mus musculus (house mouse)',
#  'mmu00061\tFatty acid biosynthesis - Mus musculus (house mouse)',
#  'mmu00062\tFatty acid elongation - Mus musculus (house mouse)',
#  'mmu00071\tFatty acid degradation - Mus musculus (house mouse)',
#  'mmu00100\tSteroid biosynthesis - Mus musculus (house mouse)',
#  'mmu00120\tPrimary bile acid biosynthesis - Mus musculus (house mouse)',
#  'mmu00140\tSteroid hormone biosynthesis - Mus musculus (house mouse)',
#  'mmu00561\tGlycerolipid metabolism - Mus musculus (house mouse)',
#  'mmu00564\tGlycerophospholipid metabolism - Mus musculus (house mouse)',
#  'mmu00565\tEther lipid metabolism - Mus musculus (house mouse)',
#  'mmu00600\tSphingolipid metabolism - Mus musculus (house mouse)',
#  'mmu00590\tArachidonic acid metabolism - Mus musculus (house mouse)',
#  'mmu00591\tLinoleic acid metabolism - Mus musculus (house mouse)',
#  'mmu00592\talpha-Linolenic acid metabolism - Mus musculus (house mouse)',
#  'mmu01040\tBiosynthesis of unsaturated fatty acids - Mus musculus (house mouse)',
#  'mmu00230\tPurine metabolism - Mus musculus (house mouse)',
#  'mmu00240\tPyrimidine metabolism - Mus musculus (house mouse)',
#  'mmu00250\tAlanine, aspartate and glutamate metabolism - Mus musculus (house mouse)',
#  'mmu00260\tGlycine, serine and threonine metabolism - Mus musculus (house mouse)',
#  'mmu00270\tCysteine and methionine metabolism - Mus musculus (house mouse)',
#  'mmu00280\tValine, leucine and isoleucine degradation - Mus musculus (house mouse)',
#  'mmu00290\tValine, leucine and isoleucine biosynthesis - Mus musculus (house mouse)',
#  'mmu00310\tLysine degradation - Mus musculus (house mouse)',
#  'mmu00220\tArginine biosynthesis - Mus musculus (house mouse)',
#  'mmu00330\tArginine and proline metabolism - Mus musculus (house mouse)',
#  'mmu00340\tHistidine metabolism - Mus musculus (house mouse)',
#  'mmu00350\tTyrosine metabolism - Mus musculus (house mouse)',
#  'mmu00360\tPhenylalanine metabolism - Mus musculus (house mouse)',
#  'mmu00380\tTryptophan metabolism - Mus musculus (house mouse)',
#  'mmu00400\tPhenylalanine, tyrosine and tryptophan biosynthesis - Mus musculus (house mouse)',
#  'mmu00410\tbeta-Alanine metabolism - Mus musculus (house mouse)',
#  'mmu00430\tTaurine and hypotaurine metabolism - Mus musculus (house mouse)',
#  'mmu00440\tPhosphonate and phosphinate metabolism - Mus musculus (house mouse)',
#  'mmu00450\tSelenocompound metabolism - Mus musculus (house mouse)',
#  'mmu00470\tD-Amino acid metabolism - Mus musculus (house mouse)',
#  'mmu00480\tGlutathione metabolism - Mus musculus (house mouse)',
#  'mmu00510\tN-Glycan biosynthesis - Mus musculus (house mouse)',
#  'mmu00513\tVarious types of N-glycan biosynthesis - Mus musculus (house mouse)',
#  'mmu00512\tMucin type O-glycan biosynthesis - Mus musculus (house mouse)',
#  'mmu00515\tMannose type O-glycan biosynthesis - Mus musculus (house mouse)',
#  'mmu00514\tOther types of O-glycan biosynthesis - Mus musculus (house mouse)',
#  'mmu00532\tGlycosaminoglycan biosynthesis - chondroitin sulfate / dermatan sulfate - Mus musculus (house mouse)',
#  'mmu00534\tGlycosaminoglycan biosynthesis - heparan sulfate / heparin - Mus musculus (house mouse)',
#  'mmu00533\tGlycosaminoglycan biosynthesis - keratan sulfate - Mus musculus (house mouse)',
#  'mmu00531\tGlycosaminoglycan degradation - Mus musculus (house mouse)',
#  'mmu00563\tGlycosylphosphatidylinositol (GPI)-anchor biosynthesis - Mus musculus (house mouse)',
#  'mmu00601\tGlycosphingolipid biosynthesis - lacto and neolacto series - Mus musculus (house mouse)',
#  'mmu00603\tGlycosphingolipid biosynthesis - globo and isoglobo series - Mus musculus (house mouse)',
#  'mmu00604\tGlycosphingolipid biosynthesis - ganglio series - Mus musculus (house mouse)',
#  'mmu00511\tOther glycan degradation - Mus musculus (house mouse)',
#  'mmu00730\tThiamine metabolism - Mus musculus (house mouse)',
#  'mmu00740\tRiboflavin metabolism - Mus musculus (house mouse)',
#  'mmu00750\tVitamin B6 metabolism - Mus musculus (house mouse)',
#  'mmu00760\tNicotinate and nicotinamide metabolism - Mus musculus (house mouse)',
#  'mmu00770\tPantothenate and CoA biosynthesis - Mus musculus (house mouse)',
#  'mmu00780\tBiotin metabolism - Mus musculus (house mouse)',
#  'mmu00785\tLipoic acid metabolism - Mus musculus (house mouse)',
#  'mmu00790\tFolate biosynthesis - Mus musculus (house mouse)',
#  'mmu00670\tOne carbon pool by folate - Mus musculus (house mouse)',
#  'mmu00830\tRetinol metabolism - Mus musculus (house mouse)',
#  'mmu00860\tPorphyrin metabolism - Mus musculus (house mouse)',
#  'mmu00130\tUbiquinone and other terpenoid-quinone biosynthesis - Mus musculus (house mouse)',
#  'mmu00900\tTerpenoid backbone biosynthesis - Mus musculus (house mouse)',
#  'mmu00232\tCaffeine metabolism - Mus musculus (house mouse)',
#  'mmu00524\tNeomycin, kanamycin and gentamicin biosynthesis - Mus musculus (house mouse)',
#  'mmu00980\tMetabolism of xenobiotics by cytochrome P450 - Mus musculus (house mouse)',
#  'mmu00982\tDrug metabolism - cytochrome P450 - Mus musculus (house mouse)',
#  'mmu00983\tDrug metabolism - other enzymes - Mus musculus (house mouse)',
#  'mmu03020\tRNA polymerase - Mus musculus (house mouse)',
#  'mmu03022\tBasal transcription factors - Mus musculus (house mouse)',
#  'mmu03040\tSpliceosome - Mus musculus (house mouse)',
#  'mmu03010\tRibosome - Mus musculus (house mouse)',
#  'mmu00970\tAminoacyl-tRNA biosynthesis - Mus musculus (house mouse)',
#  'mmu03013\tNucleocytoplasmic transport - Mus musculus (house mouse)',
#  'mmu03015\tmRNA surveillance pathway - Mus musculus (house mouse)',
#  'mmu03008\tRibosome biogenesis in eukaryotes - Mus musculus (house mouse)',
#  'mmu03060\tProtein export - Mus musculus (house mouse)',
#  'mmu04141\tProtein processing in endoplasmic reticulum - Mus musculus (house mouse)',
#  'mmu04130\tSNARE interactions in vesicular transport - Mus musculus (house mouse)',
#  'mmu04120\tUbiquitin mediated proteolysis - Mus musculus (house mouse)',
#  'mmu04122\tSulfur relay system - Mus musculus (house mouse)',
#  'mmu03050\tProteasome - Mus musculus (house mouse)',
#  'mmu03018\tRNA degradation - Mus musculus (house mouse)',
#  'mmu03030\tDNA replication - Mus musculus (house mouse)',
#  'mmu03410\tBase excision repair - Mus musculus (house mouse)',
#  'mmu03420\tNucleotide excision repair - Mus musculus (house mouse)',
#  'mmu03430\tMismatch repair - Mus musculus (house mouse)',
#  'mmu03440\tHomologous recombination - Mus musculus (house mouse)',
#  'mmu03450\tNon-homologous end-joining - Mus musculus (house mouse)',
#  'mmu03460\tFanconi anemia pathway - Mus musculus (house mouse)',
#  'mmu03082\tATP-dependent chromatin remodeling - Mus musculus (house mouse)',
#  'mmu03083\tPolycomb repressive complex - Mus musculus (house mouse)',
#  'mmu03250\tViral life cycle - HIV-1 - Mus musculus (house mouse)',
#  'mmu03260\tVirion - Human immunodeficiency virus - Mus musculus (house mouse)',
#  'mmu03271\tVirion - Rotavirus - Mus musculus (house mouse)',
#  'mmu03264\tVirion - Flavivirus - Mus musculus (house mouse)',
#  'mmu03265\tVirion - Ebolavirus, Lyssavirus and Morbillivirus - Mus musculus (house mouse)',
#  'mmu03266\tVirion - Herpesvirus - Mus musculus (house mouse)',
#  'mmu03267\tVirion - Adenovirus - Mus musculus (house mouse)',
#  'mmu02010\tABC transporters - Mus musculus (house mouse)',
#  'mmu04010\tMAPK signaling pathway - Mus musculus (house mouse)',
#  'mmu04012\tErbB signaling pathway - Mus musculus (house mouse)',
#  'mmu04014\tRas signaling pathway - Mus musculus (house mouse)',
#  'mmu04015\tRap1 signaling pathway - Mus musculus (house mouse)',
#  'mmu04310\tWnt signaling pathway - Mus musculus (house mouse)',
#  'mmu04330\tNotch signaling pathway - Mus musculus (house mouse)',
#  'mmu04340\tHedgehog signaling pathway - Mus musculus (house mouse)',
#  'mmu04350\tTGF-beta signaling pathway - Mus musculus (house mouse)',
#  'mmu04390\tHippo signaling pathway - Mus musculus (house mouse)',
#  'mmu04392\tHippo signaling pathway - multiple species - Mus musculus (house mouse)',
#  'mmu04370\tVEGF signaling pathway - Mus musculus (house mouse)',
#  'mmu04371\tApelin signaling pathway - Mus musculus (house mouse)',
#  'mmu04630\tJAK-STAT signaling pathway - Mus musculus (house mouse)',
#  'mmu04064\tNF-kappa B signaling pathway - Mus musculus (house mouse)',
#  'mmu04668\tTNF signaling pathway - Mus musculus (house mouse)',
#  'mmu04066\tHIF-1 signaling pathway - Mus musculus (house mouse)',
#  'mmu04068\tFoxO signaling pathway - Mus musculus (house mouse)',
#  'mmu04020\tCalcium signaling pathway - Mus musculus (house mouse)',
#  'mmu04070\tPhosphatidylinositol signaling system - Mus musculus (house mouse)',
#  'mmu04072\tPhospholipase D signaling pathway - Mus musculus (house mouse)',
#  'mmu04071\tSphingolipid signaling pathway - Mus musculus (house mouse)',
#  'mmu04024\tcAMP signaling pathway - Mus musculus (house mouse)',
#  'mmu04022\tcGMP-PKG signaling pathway - Mus musculus (house mouse)',
#  'mmu04151\tPI3K-Akt signaling pathway - Mus musculus (house mouse)',
#  'mmu04152\tAMPK signaling pathway - Mus musculus (house mouse)',
#  'mmu04150\tmTOR signaling pathway - Mus musculus (house mouse)',
#  'mmu04080\tNeuroactive ligand-receptor interaction - Mus musculus (house mouse)',
#  'mmu04060\tCytokine-cytokine receptor interaction - Mus musculus (house mouse)',
#  'mmu04061\tViral protein interaction with cytokine and cytokine receptor - Mus musculus (house mouse)',
#  'mmu04512\tECM-receptor interaction - Mus musculus (house mouse)',
#  'mmu04514\tCell adhesion molecules - Mus musculus (house mouse)',
#  'mmu04144\tEndocytosis - Mus musculus (house mouse)',
#  'mmu04145\tPhagosome - Mus musculus (house mouse)',
#  'mmu04142\tLysosome - Mus musculus (house mouse)',
#  'mmu04146\tPeroxisome - Mus musculus (house mouse)',
#  'mmu04140\tAutophagy - animal - Mus musculus (house mouse)',
#  'mmu04136\tAutophagy - other - Mus musculus (house mouse)',
#  'mmu04137\tMitophagy - animal - Mus musculus (house mouse)',
#  'mmu04148\tEfferocytosis - Mus musculus (house mouse)',
#  'mmu04110\tCell cycle - Mus musculus (house mouse)',
#  'mmu04114\tOocyte meiosis - Mus musculus (house mouse)',
#  'mmu04210\tApoptosis - Mus musculus (house mouse)',
#  'mmu04215\tApoptosis - multiple species - Mus musculus (house mouse)',
#  'mmu04216\tFerroptosis - Mus musculus (house mouse)',
#  'mmu04217\tNecroptosis - Mus musculus (house mouse)',
#  'mmu04115\tp53 signaling pathway - Mus musculus (house mouse)',
#  'mmu04218\tCellular senescence - Mus musculus (house mouse)',
#  'mmu04510\tFocal adhesion - Mus musculus (house mouse)',
#  'mmu04520\tAdherens junction - Mus musculus (house mouse)',
#  'mmu04530\tTight junction - Mus musculus (house mouse)',
#  'mmu04540\tGap junction - Mus musculus (house mouse)',
#  'mmu04550\tSignaling pathways regulating pluripotency of stem cells - Mus musculus (house mouse)',
#  'mmu04814\tMotor proteins - Mus musculus (house mouse)',
#  'mmu04820\tCytoskeleton in muscle cells - Mus musculus (house mouse)',
#  'mmu04810\tRegulation of actin cytoskeleton - Mus musculus (house mouse)',
#  'mmu04640\tHematopoietic cell lineage - Mus musculus (house mouse)',
#  'mmu04610\tComplement and coagulation cascades - Mus musculus (house mouse)',
#  'mmu04611\tPlatelet activation - Mus musculus (house mouse)',
#  'mmu04613\tNeutrophil extracellular trap formation - Mus musculus (house mouse)',
#  'mmu04620\tToll-like receptor signaling pathway - Mus musculus (house mouse)',
#  'mmu04621\tNOD-like receptor signaling pathway - Mus musculus (house mouse)',
#  'mmu04622\tRIG-I-like receptor signaling pathway - Mus musculus (house mouse)',
#  'mmu04623\tCytosolic DNA-sensing pathway - Mus musculus (house mouse)',
#  'mmu04625\tC-type lectin receptor signaling pathway - Mus musculus (house mouse)',
#  'mmu04650\tNatural killer cell mediated cytotoxicity - Mus musculus (house mouse)',
#  'mmu04612\tAntigen processing and presentation - Mus musculus (house mouse)',
#  'mmu04660\tT cell receptor signaling pathway - Mus musculus (house mouse)',
#  'mmu04658\tTh1 and Th2 cell differentiation - Mus musculus (house mouse)',
#  'mmu04659\tTh17 cell differentiation - Mus musculus (house mouse)',
#  'mmu04657\tIL-17 signaling pathway - Mus musculus (house mouse)',
#  'mmu04662\tB cell receptor signaling pathway - Mus musculus (house mouse)',
#  'mmu04664\tFc epsilon RI signaling pathway - Mus musculus (house mouse)',
#  'mmu04666\tFc gamma R-mediated phagocytosis - Mus musculus (house mouse)',
#  'mmu04670\tLeukocyte transendothelial migration - Mus musculus (house mouse)',
#  'mmu04672\tIntestinal immune network for IgA production - Mus musculus (house mouse)',
#  'mmu04062\tChemokine signaling pathway - Mus musculus (house mouse)',
#  'mmu04911\tInsulin secretion - Mus musculus (house mouse)',
#  'mmu04910\tInsulin signaling pathway - Mus musculus (house mouse)',
#  'mmu04922\tGlucagon signaling pathway - Mus musculus (house mouse)',
#  'mmu04923\tRegulation of lipolysis in adipocytes - Mus musculus (house mouse)',
#  'mmu04920\tAdipocytokine signaling pathway - Mus musculus (house mouse)',
#  'mmu03320\tPPAR signaling pathway - Mus musculus (house mouse)',
#  'mmu04929\tGnRH secretion - Mus musculus (house mouse)',
#  'mmu04912\tGnRH signaling pathway - Mus musculus (house mouse)',
#  'mmu04913\tOvarian steroidogenesis - Mus musculus (house mouse)',
#  'mmu04915\tEstrogen signaling pathway - Mus musculus (house mouse)',
#  'mmu04914\tProgesterone-mediated oocyte maturation - Mus musculus (house mouse)',
#  'mmu04917\tProlactin signaling pathway - Mus musculus (house mouse)',
#  'mmu04921\tOxytocin signaling pathway - Mus musculus (house mouse)',
#  'mmu04926\tRelaxin signaling pathway - Mus musculus (house mouse)',
#  'mmu04935\tGrowth hormone synthesis, secretion and action - Mus musculus (house mouse)',
#  'mmu04918\tThyroid hormone synthesis - Mus musculus (house mouse)',
#  'mmu04919\tThyroid hormone signaling pathway - Mus musculus (house mouse)',
#  'mmu04928\tParathyroid hormone synthesis, secretion and action - Mus musculus (house mouse)',
#  'mmu04916\tMelanogenesis - Mus musculus (house mouse)',
#  'mmu04924\tRenin secretion - Mus musculus (house mouse)',
#  'mmu04614\tRenin-angiotensin system - Mus musculus (house mouse)',
#  'mmu04925\tAldosterone synthesis and secretion - Mus musculus (house mouse)',
#  'mmu04927\tCortisol synthesis and secretion - Mus musculus (house mouse)',
#  'mmu04260\tCardiac muscle contraction - Mus musculus (house mouse)',
#  'mmu04261\tAdrenergic signaling in cardiomyocytes - Mus musculus (house mouse)',
#  'mmu04270\tVascular smooth muscle contraction - Mus musculus (house mouse)',
#  'mmu04970\tSalivary secretion - Mus musculus (house mouse)',
#  'mmu04971\tGastric acid secretion - Mus musculus (house mouse)',
#  'mmu04972\tPancreatic secretion - Mus musculus (house mouse)',
#  'mmu04976\tBile secretion - Mus musculus (house mouse)',
#  'mmu04973\tCarbohydrate digestion and absorption - Mus musculus (house mouse)',
#  'mmu04974\tProtein digestion and absorption - Mus musculus (house mouse)',
#  'mmu04975\tFat digestion and absorption - Mus musculus (house mouse)',
#  'mmu04979\tCholesterol metabolism - Mus musculus (house mouse)',
#  'mmu04977\tVitamin digestion and absorption - Mus musculus (house mouse)',
#  'mmu04980\tCobalamin transport and metabolism - Mus musculus (house mouse)',
#  'mmu04978\tMineral absorption - Mus musculus (house mouse)',
#  'mmu04962\tVasopressin-regulated water reabsorption - Mus musculus (house mouse)',
#  'mmu04960\tAldosterone-regulated sodium reabsorption - Mus musculus (house mouse)',
#  'mmu04961\tEndocrine and other factor-regulated calcium reabsorption - Mus musculus (house mouse)',
#  'mmu04964\tProximal tubule bicarbonate reclamation - Mus musculus (house mouse)',
#  'mmu04966\tCollecting duct acid secretion - Mus musculus (house mouse)',
#  'mmu04724\tGlutamatergic synapse - Mus musculus (house mouse)',
#  'mmu04727\tGABAergic synapse - Mus musculus (house mouse)',
#  'mmu04725\tCholinergic synapse - Mus musculus (house mouse)',
#  'mmu04728\tDopaminergic synapse - Mus musculus (house mouse)',
#  'mmu04726\tSerotonergic synapse - Mus musculus (house mouse)',
#  'mmu04720\tLong-term potentiation - Mus musculus (house mouse)',
#  'mmu04730\tLong-term depression - Mus musculus (house mouse)',
#  'mmu04723\tRetrograde endocannabinoid signaling - Mus musculus (house mouse)',
#  'mmu04721\tSynaptic vesicle cycle - Mus musculus (house mouse)',
#  'mmu04722\tNeurotrophin signaling pathway - Mus musculus (house mouse)',
#  'mmu04744\tPhototransduction - Mus musculus (house mouse)',
#  'mmu04740\tOlfactory transduction - Mus musculus (house mouse)',
#  'mmu04742\tTaste transduction - Mus musculus (house mouse)',
#  'mmu04750\tInflammatory mediator regulation of TRP channels - Mus musculus (house mouse)',
#  'mmu04360\tAxon guidance - Mus musculus (house mouse)',
#  'mmu04380\tOsteoclast differentiation - Mus musculus (house mouse)',
#  'mmu04211\tLongevity regulating pathway - Mus musculus (house mouse)',
#  'mmu04213\tLongevity regulating pathway - multiple species - Mus musculus (house mouse)',
#  'mmu04710\tCircadian rhythm - Mus musculus (house mouse)',
#  'mmu04713\tCircadian entrainment - Mus musculus (house mouse)',
#  'mmu04714\tThermogenesis - Mus musculus (house mouse)',
#  'mmu05200\tPathways in cancer - Mus musculus (house mouse)',
#  'mmu05202\tTranscriptional misregulation in cancer - Mus musculus (house mouse)',
#  'mmu05206\tMicroRNAs in cancer - Mus musculus (house mouse)',
#  'mmu05205\tProteoglycans in cancer - Mus musculus (house mouse)',
#  'mmu05204\tChemical carcinogenesis - DNA adducts - Mus musculus (house mouse)',
#  'mmu05207\tChemical carcinogenesis - receptor activation - Mus musculus (house mouse)',
#  'mmu05208\tChemical carcinogenesis - reactive oxygen species - Mus musculus (house mouse)',
#  'mmu05203\tViral carcinogenesis - Mus musculus (house mouse)',
#  'mmu05230\tCentral carbon metabolism in cancer - Mus musculus (house mouse)',
#  'mmu05231\tCholine metabolism in cancer - Mus musculus (house mouse)',
#  'mmu05235\tPD-L1 expression and PD-1 checkpoint pathway in cancer - Mus musculus (house mouse)',
#  'mmu05210\tColorectal cancer - Mus musculus (house mouse)',
#  'mmu05212\tPancreatic cancer - Mus musculus (house mouse)',
#  'mmu05225\tHepatocellular carcinoma - Mus musculus (house mouse)',
#  'mmu05226\tGastric cancer - Mus musculus (house mouse)',
#  'mmu05214\tGlioma - Mus musculus (house mouse)',
#  'mmu05216\tThyroid cancer - Mus musculus (house mouse)',
#  'mmu05221\tAcute myeloid leukemia - Mus musculus (house mouse)',
#  'mmu05220\tChronic myeloid leukemia - Mus musculus (house mouse)',
#  'mmu05217\tBasal cell carcinoma - Mus musculus (house mouse)',
#  'mmu05218\tMelanoma - Mus musculus (house mouse)',
#  'mmu05211\tRenal cell carcinoma - Mus musculus (house mouse)',
#  'mmu05219\tBladder cancer - Mus musculus (house mouse)',
#  'mmu05215\tProstate cancer - Mus musculus (house mouse)',
#  'mmu05213\tEndometrial cancer - Mus musculus (house mouse)',
#  'mmu05224\tBreast cancer - Mus musculus (house mouse)',
#  'mmu05222\tSmall cell lung cancer - Mus musculus (house mouse)',
#  'mmu05223\tNon-small cell lung cancer - Mus musculus (house mouse)',
#  'mmu05166\tHuman T-cell leukemia virus 1 infection - Mus musculus (house mouse)',
#  'mmu05170\tHuman immunodeficiency virus 1 infection - Mus musculus (house mouse)',
#  'mmu05161\tHepatitis B - Mus musculus (house mouse)',
#  'mmu05160\tHepatitis C - Mus musculus (house mouse)',
#  'mmu05171\tCoronavirus disease - COVID-19 - Mus musculus (house mouse)',
#  'mmu05164\tInfluenza A - Mus musculus (house mouse)',
#  'mmu05162\tMeasles - Mus musculus (house mouse)',
#  'mmu05168\tHerpes simplex virus 1 infection - Mus musculus (house mouse)',
#  'mmu05163\tHuman cytomegalovirus infection - Mus musculus (house mouse)',
#  'mmu05167\tKaposi sarcoma-associated herpesvirus infection - Mus musculus (house mouse)',
#  'mmu05169\tEpstein-Barr virus infection - Mus musculus (house mouse)',
#  'mmu05165\tHuman papillomavirus infection - Mus musculus (house mouse)',
#  'mmu05132\tSalmonella infection - Mus musculus (house mouse)',
#  'mmu05135\tYersinia infection - Mus musculus (house mouse)',
#  'mmu05133\tPertussis - Mus musculus (house mouse)',
#  'mmu05134\tLegionellosis - Mus musculus (house mouse)',
#  'mmu05150\tStaphylococcus aureus infection - Mus musculus (house mouse)',
#  'mmu05152\tTuberculosis - Mus musculus (house mouse)',
#  'mmu05100\tBacterial invasion of epithelial cells - Mus musculus (house mouse)',
#  'mmu05146\tAmoebiasis - Mus musculus (house mouse)',
#  'mmu05144\tMalaria - Mus musculus (house mouse)',
#  'mmu05145\tToxoplasmosis - Mus musculus (house mouse)',
#  'mmu05140\tLeishmaniasis - Mus musculus (house mouse)',
#  'mmu05142\tChagas disease - Mus musculus (house mouse)',
#  'mmu05143\tAfrican trypanosomiasis - Mus musculus (house mouse)',
#  'mmu05310\tAsthma - Mus musculus (house mouse)',
#  'mmu05322\tSystemic lupus erythematosus - Mus musculus (house mouse)',
#  'mmu05323\tRheumatoid arthritis - Mus musculus (house mouse)',
#  'mmu05320\tAutoimmune thyroid disease - Mus musculus (house mouse)',
#  'mmu05321\tInflammatory bowel disease - Mus musculus (house mouse)',
#  'mmu05330\tAllograft rejection - Mus musculus (house mouse)',
#  'mmu05332\tGraft-versus-host disease - Mus musculus (house mouse)',
#  'mmu05340\tPrimary immunodeficiency - Mus musculus (house mouse)',
#  'mmu05010\tAlzheimer disease - Mus musculus (house mouse)',
#  'mmu05012\tParkinson disease - Mus musculus (house mouse)',
#  'mmu05014\tAmyotrophic lateral sclerosis - Mus musculus (house mouse)',
#  'mmu05016\tHuntington disease - Mus musculus (house mouse)',
#  'mmu05017\tSpinocerebellar ataxia - Mus musculus (house mouse)',
#  'mmu05020\tPrion disease - Mus musculus (house mouse)',
#  'mmu05022\tPathways of neurodegeneration - multiple diseases - Mus musculus (house mouse)',
#  'mmu05030\tCocaine addiction - Mus musculus (house mouse)',
#  'mmu05031\tAmphetamine addiction - Mus musculus (house mouse)',
#  'mmu05032\tMorphine addiction - Mus musculus (house mouse)',
#  'mmu05033\tNicotine addiction - Mus musculus (house mouse)',
#  'mmu05034\tAlcoholism - Mus musculus (house mouse)',
#  'mmu05417\tLipid and atherosclerosis - Mus musculus (house mouse)',
#  'mmu05418\tFluid shear stress and atherosclerosis - Mus musculus (house mouse)',
#  'mmu05410\tHypertrophic cardiomyopathy - Mus musculus (house mouse)',
#  'mmu05412\tArrhythmogenic right ventricular cardiomyopathy - Mus musculus (house mouse)',
#  'mmu05414\tDilated cardiomyopathy - Mus musculus (house mouse)',
#  'mmu05415\tDiabetic cardiomyopathy - Mus musculus (house mouse)',
#  'mmu05416\tViral myocarditis - Mus musculus (house mouse)',
#  'mmu04930\tType II diabetes mellitus - Mus musculus (house mouse)',
#  'mmu04940\tType I diabetes mellitus - Mus musculus (house mouse)',
#  'mmu04950\tMaturity onset diabetes of the young - Mus musculus (house mouse)',
#  'mmu04936\tAlcoholic liver disease - Mus musculus (house mouse)',
#  'mmu04932\tNon-alcoholic fatty liver disease - Mus musculus (house mouse)',
#  'mmu04931\tInsulin resistance - Mus musculus (house mouse)',
#  'mmu04933\tAGE-RAGE signaling pathway in diabetic complications - Mus musculus (house mouse)',
#  'mmu04934\tCushing syndrome - Mus musculus (house mouse)',
#  'mmu01521\tEGFR tyrosine kinase inhibitor resistance - Mus musculus (house mouse)',
#  'mmu01524\tPlatinum drug resistance - Mus musculus (house mouse)',
#  'mmu01523\tAntifolate resistance - Mus musculus (house mouse)',
#  'mmu01522\tEndocrine resistance - Mus musculus (house mouse)',
#  '']

# %%
# Filter all pathways for repair pathways
repair_pathways = []
for line in mouse_pathways.rstrip().split("\n"):
    entry, description = line.split("\t")
    if "homologous" in description:
        repair_pathways.append(entry)

repair_pathways
# Out:
# ['mmu03450']

# %%
repair_pathways = [
    "mmu03460", # Fanconi Anemia,
    "mmu03450", # Non-homologous end joining
    "mmu03440"
]

# %%
# Get the genes for pathways and add them to a list
pathway_genes = {}
for pathway in repair_pathways:
    pathway_genes[pathway] = []
    pathway_file = REST.kegg_get(pathway).read()  # query and read each pathway

    # iterate through each KEGG pathway file, keeping track of which section
    # of the file we're in, only read the gene in each pathway
    current_section = None
    for line in pathway_file.rstrip().split("\n"):
        section = line[:12].strip()  # section names are within 12 columns
        if not section == "":
            current_section = section

        if current_section == "GENE":
            gene_identifiers, gene_description = line[12:].split("; ")
            gene_id, gene_symbol = gene_identifiers.split()

            if not gene_symbol in pathway_genes[pathway]:
                pathway_genes[pathway].append(gene_symbol)

# print(pathway_genes.keys())
# print(pathway_genes)

for p in repair_pathways:
    print(p)
    print(pathway_genes[p])
    print("\n")
# Out:
# mmu03460
# ['Atrip', 'Atr', 'Fancm', 'Faap24', 'Cenps', 'Cenpx', 'Telo2', 'Hes1', 'Faap100', 'Fanca', 'Fancb', 'Fancc', 'Fance', 'Fancf', 'Fancg', 'Fancl', 'Wdr48', 'Usp1', 'Ube2t', 'Fanci', 'Fancd2', 'Brca2', 'Palb2', 'Rad51c', 'Rad51', 'Brca1', 'Brip1', 'Fan1', 'Mlh1', 'Pms2', 'Rev1', 'Rev3l', 'Polh', 'Poli', 'Polk', 'Poln', 'Rmi1', 'Rmi2', 'Top3b', 'Top3a', 'Blm', 'Rpa1', 'Rpa2', 'Rpa3', 'Gm6195', 'Mus81', 'Eme1', 'Eme2', 'Ercc4', 'Ercc1', 'Slx1b', 'Slx4']
#
#
# mmu03450
# ['Xrcc6', 'Xrcc5', 'Dclre1c', 'Prkdc', 'Poll', 'Polm', 'Dntt', 'Lig4', 'Xrcc4', 'Nhej1', 'Rad50', 'Mre11a', 'Fen1']
#
#
# mmu03440
# ['Ssbp1', 'Rad50', 'Mre11a', 'Nbn', 'Atm', 'Brca1', 'Bard1', 'Rbbp8', 'Brip1', 'Topbp1', 'Abraxas1', 'Uimc1', 'Babam1', 'Babam2', 'Brcc3', 'Brcc3dc', 'Palb2', 'Brca2', 'Sem1', 'Sycp3', 'Rpa1', 'Rpa2', 'Rpa3', 'Gm6195', 'Rad51', 'Rad52', 'Rad51b', 'Rad51c', 'Rad51d', 'Xrcc2', 'Xrcc3', 'Rad54l', 'Rad54b', 'Pold1', 'Pold2', 'Pold3', 'Pold4', 'Blm', 'Top3b', 'Top3a', 'Mus81', 'Eme1']

# %%
# polymerases

polymerases = REST.kegg_find("mmu", "polymerase").read().split("\n")
all_polys = []
for p in polymerases:
    ps = p.split("\t")
    if len(ps) > 1:
        all_polys.append(ps[1].split(",")[0].split(";")[0])

[p for p in all_polys if "Pol" in p]
# Out:
# ['Polr1f',
#  'Polr1h',
#  'Polr2e',
#  'Polr2k',
#  'Polr3d',
#  'Polr3f',
#  'Polr1e',
#  'Polr3g',
#  'Polr2b',
#  'Polr1d',
#  'Polr3gl',
#  'Pole2',
#  'Polr1c',
#  'Polg2',
#  'Polm',
#  'Polb',
#  'Polr1a',
#  'Pold4',
#  'Polr1g',
#  'Pold2',
#  'Polr2g',
#  'Polrmt',
#  'Polr1b',
#  'Poli',
#  'Polr3a',
#  'Pole3',
#  'Pola2',
#  'Polg',
#  'Polr2m',
#  'Polh',
#  'Polr2l',
#  'Polr1has',
#  'Polr2j',
#  'Pole4',
#  'Pola1',
#  'Pold1',
#  'Polr3k',
#  'Polr2i',
#  'Polr2c',
#  'Polr3h',
#  'Polr2f',
#  'Poll',
#  'Poldip3',
#  'Polr2d',
#  'Pold3',
#  'Polr3b',
#  'Polr3e',
#  'Polr2h',
#  'Poldip2',
#  'Polr3c',
#  'Poln',
#  'Pole',
#  'Polq',
#  'Polk',
#  'Polr2a']

# %% [markdown]
# ### Downloading KGML object

# %%
# from Bio import SeqIO
# from Bio.KEGG.REST import *
# from Bio.KEGG.KGML import KGML_parser
# from Bio.Graphics.KGML_vis import KGMLCanvas
# from Bio.Graphics.ColorSpiral import ColorSpiral

# %%
# # A bit of helper code to shorten long text
# def head(text, lines=10):
#     """Print the first lines lines of the passed text."""
#     print('\n'.join(text.split('\n')[:lines] + ['[...]']))

# %%
# head(kegg_list('mmu03450').read())

# %%
# import os

# kegg_dir = "artifacts/kegg"
# pathway = "mmu03450"
# pathway_file_path = "{}/{}.xml".format(kegg_dir, pathway)
# os.makedirs(kegg_dir, exist_ok=True)
# ko_map = (kegg_get("mmu03450", "kgml").read())
# pathway_file = open(pathway_file_path, "w")
# pathway_file.write(ko_map)
# pathway_file.close()

# %%
# from src.parse_KGML import *

# (tree, pathway, nodes, genes) = KGML2Graph(pathway_file_path)

# %%
# pathway.reactions
