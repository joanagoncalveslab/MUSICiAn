# %%
# OPTIONAL: Load the "autoreload" eX_orig[alias]tension so that code can change
# %load_ext autoreload

# OPTIONAL: always reload modules so that as you change code in src, it gets loaded
# %autoreload 2

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import umap
import seaborn as sns
import pandas as pd
import numpy as np
import pickle as pkl
import matplotlib.pyplot as plt
from adjustText import adjust_text
from sklearn.covariance import MinCovDet

from src.util import calculate_difference_to_controls
from src.config import get_hussmann_supplementary_xlsx, get_experiment_artifacts, PAIRED_SAMPLES, SAMPLE
from src.models.outliers import logratio_outlier_detection

# %% [markdown]
# # UMAP Visualisations
#
# - Load sample data
# - Get actual controls
# - Calculate differential profiles
# - Plot UMAP

# %%
Z = pkl.load(open("{}/imputed_adamson_sample_data.pkl".format(get_experiment_artifacts(profile_type=SAMPLE)), "rb"))
d = pd.concat(Z, axis=1)
d.shape
# Out:
# (496, 14)

# %%
d.head()
# Out:
#               K562_SpCas9_target-1_HDR_oBA701_AX227_rep_1  \
# lumc_category                  Deletion 0bp microhomology
# Gene
# Actl6a                                           0.176425
# Actr5                                            0.181376
# Actr8                                            0.190534
# Aicda                                            0.184504
# Alkbh2                                           0.189304
#
#                                                                      \
# lumc_category Deletion 1bp microhomology Deletion 2bp microhomology
# Gene
# Actl6a                          0.362053                   0.049512
# Actr5                           0.369397                   0.039925
# Actr8                           0.373348                   0.049253
# Aicda                           0.364239                   0.056348
# Alkbh2                          0.356852                   0.054539
#
# ...

# %%
controls = d.index[d.index.str.contains("non-")].to_list()
controls[:5]
# Out:
# ['non-targeting_000',
#  'non-targeting_001',
#  'non-targeting_002',
#  'non-targeting_003',
#  'non-targeting_005']

# %%
Xall = d.stack().stack()\
    .to_frame().reset_index()\
    .rename(columns={"level_2": "Sample", 0: "Value"})\
    .pivot(index=["Sample", "Gene"], columns=["lumc_category"], values="Value")

# %%
Xdiff = calculate_difference_to_controls(Xall, controls, d.columns.unique(0), return_log2_fold_change=False)
Xdiff.head()
# Out:
# (992, 7)
# (58, 7)
# (496, 14)
# (14,)
# (496, 14)
# Sample        K562_SpCas9_target-1_HDR_oBA701_AX227_rep_1  \
# lumc_category                               Any Insertion
# Gene
# Actl6a                                           0.039872
# Actr5                                            0.021219
# Actr8                                            0.004412
# Aicda                                           -0.000591
# Alkbh2                                           0.000948
#
# Sample                                                               \
# lumc_category Deletion 0bp microhomology Deletion 1bp microhomology
# Gene
# Actl6a                         -0.012454                  -0.002015
# Actr5                          -0.007504                   0.005328
# Actr8                           0.001654                   0.009280
# Aicda                          -0.004376                   0.000170
# Alkbh2                          0.000424                  -0.007217
#
# ...

# %%
adamson_data = pd.read_excel(get_hussmann_supplementary_xlsx(4), sheet_name="Table S4", skiprows=1)
adamson_data.head()
# Out:
#      Gene             Plot Annotation  \
# 0  ACTL6A         Chromatin processes
# 1   ACTR5  Double-strand break repair
# 2   ACTR8  Double-strand break repair
# 3   AICDA         Chromatin processes
# 4  ALKBH2                  DNA repair
#
#                                      All Annotations Gene.1  \
# 0  Chromatin remodeling, Histone acetylation, His...   APTX
# 1  Cellular response to DNA damage stimulus, Chro...  ASCC3
# 2  Cellular response to DNA damage stimulus, Chro...    ATM
# 3  Demethylation, DNA metabolic process, Nucleic ...    ATR
# 4  Cellular response to DNA damage stimulus, Deme...  ATRIP
#
#             Plot Annotation.1  \
# 0  Double-strand break repair
# 1                  DNA repair
# 2       Cell cycle checkpoint
# 3       Cell cycle checkpoint
# 4                  DNA repair
#
#                                    All Annotations.1
# 0  Cellular response to DNA damage stimulus, DNA ...
# 1  Cellular response to DNA damage stimulus, DNA ...
# ...

# %%
full_adamson_set = False

if full_adamson_set:
    annotations = "All Annotations"
    genes = "Gene"
else:
    annotations = "All Annotations.1"
    genes = "Gene.1"

pathway_binary_df = adamson_data[annotations].dropna().str.replace(", ", ",").str.get_dummies(sep=",")
pathway_binary_df[genes] = adamson_data[genes].dropna().str.capitalize()
pathway_binary_df = pathway_binary_df.set_index(genes)
pathway_binary_df.head()
# Out:
#         Base-excision repair  Cell cycle checkpoint  \
# Gene.1
# Aptx                       0                      0
# Ascc3                      0                      0
# Atm                        0                      1
# Atr                        0                      1
# Atrip                      0                      1
#
#         Cellular response to DNA damage stimulus  Chromatin remodeling  \
# Gene.1
# Aptx                                           1                     0
# Ascc3                                          1                     0
# Atm                                            1                     0
# Atr                                            1                     0
# Atrip                                          1                     0
#
#         DNA conformation change  DNA damage checkpoint  DNA metabolic process  \
# Gene.1
# Aptx                          0                      0                      1
# ...

# %%
pathway_binary_df.shape
# Out:
# (118, 33)

# %%
pathway_binary_df.sum().sort_values()[::-1]
# Out:
# DNA metabolic process                                                 85
# Cellular response to DNA damage stimulus                              76
# DNA repair                                                            70
# DNA replication                                                       37
# Double-strand break repair                                            37
# Cell cycle checkpoint                                                 18
# Nuclear division                                                      18
# DNA conformation change                                               18
# DNA damage checkpoint                                                 16
# Protein modification process                                          16
# Nucleic acid phosphodiester bond hydrolysis                           13
# Regulation of transcription by RNA polymerase II                      13
# RNA biosynthetic process                                              12
# ...

# %%
adamson_genes = list(np.intersect1d(Xdiff.index, pathway_binary_df.index))

# %%
Xdiff = Xdiff.loc[adamson_genes]

# %%
Xdiff.head()
# Out:
# Sample        K562_SpCas9_target-1_HDR_oBA701_AX227_rep_1  \
# lumc_category                               Any Insertion
# Gene
# Aptx                                             0.048497
# Ascc3                                            0.018809
# Atm                                             -0.015913
# Atr                                             -0.010631
# Atrip                                            0.007842
#
# Sample                                                               \
# lumc_category Deletion 0bp microhomology Deletion 1bp microhomology
# Gene
# Aptx                           -0.009479                  -0.027221
# Ascc3                           0.001291                   0.026425
# Atm                            -0.023896                  -0.033155
# Atr                             0.018733                   0.107263
# Atrip                           0.013357                   0.057412
#
# ...

# %%
def draw_umap(data, n_neighbors=10, min_dist=0.1, n_components=2, metric='euclidean', title='', hue=None, hue_order=None, labels=None, correct_labels=True, figsize=(6, 5), palette="tab10", legend=True):
    np.random.seed(42)
    fit = umap.UMAP(
        n_neighbors=n_neighbors,
        min_dist=min_dist,
        n_components=n_components,
        metric=metric,
        random_state=1
    )
    u = fit.fit_transform(data)
    plot_embedding(u, title=title, hue=hue, hue_order=hue_order, labels=labels, correct_labels=correct_labels, figsize=figsize, palette=palette, legend=legend)
    return u

def plot_embedding(u, title=None, hue=None, hue_order=None, labels=None, correct_labels=True, figsize=(6, 5), palette="tab10", legend=True):
    fig = plt.figure(figsize=figsize)
    ax = fig.add_subplot(111)
    sns.scatterplot(x= u[:, 0], y= u[:, 1], ax=ax, hue=hue, hue_order=hue_order, palette=palette, alpha=0.5)
    if title is not None:
        plt.title(title, fontsize=10.5)
    if labels is not None:
        texts = [plt.text(u[i, 0], u[i, 1], l, fontsize=6) for i, l in enumerate(labels.values) if l != '']
        if correct_labels:
            adjust_text(texts)
    if legend:
        plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
    else:
        ax.get_legend().remove()
    plt.tight_layout()

def get_labels(Xdiff, labels_to_plot):
    labels = pd.Series(np.repeat("", Xdiff.shape[0]), index=Xdiff.index)
    inter_labels = np.intersect1d(Xdiff.index, labels_to_plot)
    labels[inter_labels] = inter_labels
    return labels

# %%
# def assign_palette(results, axis):
#     if 'cluster_assignments' in results:
#         num_clusters = len(set(results['cluster_assignments']))

#         if axis == 'guides':
#             palette = sns.husl_palette(num_clusters)
#         elif axis == 'outcomes':
#             palette = sns.color_palette('muted', n_colors=num_clusters)
#         else:
#             raise ValueError(axis)

#         results['palette'] = palette
#         grey = matplotlib.colors.to_rgb('silver')
#         cluster_colors = {i: palette[i] for i in range(num_clusters)}
#         results['cluster_colors'] = cluster_colors

#         results['colors'] = {key: cluster_colors.get(i, grey) for key, i in zip(results['clustered_order'], results['cluster_assignments'])}
# log2_fold_changes

# results = HDBSCAN(log2_fold_changes, 'guides')
# assign_palette(results, 'guides')
# guide_clustering = results

# %%
Xdiff
# Out:
# Sample        K562_SpCas9_target-1_HDR_oBA701_AX227_rep_1  \
# lumc_category                               Any Insertion
# Gene
# Aptx                                             0.048497
# Ascc3                                            0.018809
# Atm                                             -0.015913
# Atr                                             -0.010631
# Atrip                                            0.007842
# ...                                                   ...
# Vps72                                            0.020849
# Wapal                                            0.005608
# Wrn                                              0.042579
# Xrcc5                                            0.070965
# Xrcc6                                            0.055267
#
# Sample                                                               \
# lumc_category Deletion 0bp microhomology Deletion 1bp microhomology
# Gene
# ...

# %%
cluster_assignments_df = pkl.load(open("artifacts/adamson_cluster_assignments.pkl", "rb"))
cluster_assignments_df.head().iloc[0,:]["color"]
# Out:
# (0.7529411764705882, 0.7529411764705882, 0.7529411764705882)

# %%
cluster_assignments_df["Gene"] = cluster_assignments_df.index.to_series().str.split("_", expand=True)[0].str.capitalize()
# cluster_assignments_df[["cluster_assignments_df"]].value_counts()
colors = cluster_assignments_df[["Gene", "color", "cluster_assignments"]].reset_index(drop=True).drop_duplicates().set_index("Gene").to_dict()["color"]
in_cluster_genes = cluster_assignments_df.loc[cluster_assignments_df["cluster_assignments"] != -1]["Gene"].unique()

for i in Xdiff.index.to_list():
    if i not in colors:
        colors[i] = (0.7529411764705882, 0.7529411764705882, 0.7529411764705882)

# %%
# u = draw_umap(Xdiff, n_neighbors=10, min_dist=0.1, n_components=2, metric='cosine', hue=Xdiff.index.to_list(),
#             title='Adamson data, MUSICian mutational profiles', 
#             palette=colors, legend=False, labels=Xdiff.index.to_series())

u = draw_umap(Xdiff, n_neighbors=10, min_dist=0.1, n_components=2, metric='cosine', hue=Xdiff.index.to_list(),
            palette=colors, legend=False, labels=get_labels(Xdiff, in_cluster_genes), correct_labels=False)
plt.savefig("artifacts/adamson_umap_{}.pdf".format("full" if full_adamson_set else "reduced" ))
plt.show()

# %%
fanconi = ['Atrip', 'Atr', 'Fancm', 'Faap24', 'Cenps', 'Cenpx', 'Telo2', 'Hes1'\
 , 'Faap100', 'Fanca', 'Fancb', 'Fancc', 'Fance', 'Fancf', 'Fancg', 'Fancl'\
    , 'Wdr48', 'Usp1', 'Ube2t', 'Fanci', 'Fancd2', 'Brca2', 'Palb2', 'Rad51c'\
        , 'Rad51', 'Brca1', 'Brip1', 'Fan1', 'Mlh1', 'Pms2', 'Rev1', 'Rev3l', 'Polh'\
            , 'Poli', 'Polk', 'Poln', 'Rmi1', 'Rmi2', 'Top3b', 'Top3a', 'Blm', 'Rpa1', 'Rpa2'\
                , 'Rpa3', 'Mus81', 'Eme1', 'Eme2', 'Ercc4', 'Ercc1', 'Slx1b', 'Slx4']
regex_str = "|".join(fanconi)


u = draw_umap(Xdiff, n_neighbors=10, min_dist=0.1, n_components=2, metric='cosine', 
            title='Fanconi Anemia', 
            hue=Xdiff.index.get_level_values(0).str.contains(regex_str), hue_order=[True, False], labels=get_labels(Xdiff, fanconi))
plt.savefig("artifacts/fanconi_anemia_adamson_umap_{}.pdf".format("full" if full_adamson_set else "reduced" ))
plt.show()

# %%
HR = ['Ssbp1', 'Rad50', 'Mre11a', 'Nbn', 'Atm', 'Brca1', 'Bard1', 'Rbbp8', 'Brip1', 'Topbp1'\
      , 'Abraxas1', 'Uimc1', 'Babam1', 'Babam2', 'Brcc3', 'Brcc3dc', 'Palb2', 'Brca2', 'Sem1'\
        , 'Sycp3', 'Rpa1', 'Rpa2', 'Rpa3', 'Rad51', 'Rad52', 'Rad51b', 'Rad51c', 'Rad51d', 'Xrcc2', 'Xrcc3', 'Rad54l'\
      , 'Rad54b', 'Pold1', 'Pold2', 'Pold3', 'Pold4', 'Blm', 'Top3b', 'Top3a', 'Mus81', 'Eme1']
regex_str = "|".join(HR)
u = draw_umap(Xdiff, n_neighbors=10, min_dist=0.1, n_components=2, metric='cosine', 
            title='HR', 
            hue=Xdiff.index.get_level_values("Gene").str.contains(regex_str), hue_order=[True, False], labels=get_labels(Xdiff, HR))
plt.savefig("artifacts/HR_adamson_umap_{}.pdf".format("full" if full_adamson_set else "reduced" ))
plt.show()

# %%
NHEJ = ['Xrcc6', 'Xrcc5', 'Dclre1c', 'Prkdc', 'Poll', 'Polm', 'Dntt', 'Lig4', 'Xrcc4', 'Nhej1', 'Rad50', 'Mre11a', 'Fen1']
regex_str = "|".join(NHEJ)
u = draw_umap(Xdiff, n_neighbors=10, min_dist=0.1, n_components=2, metric='cosine', 
            title='NHEJ', 
            hue=Xdiff.index.get_level_values("Gene").str.contains(regex_str), hue_order=[True, False], labels=get_labels(Xdiff, NHEJ))
plt.savefig("artifacts/NHEJ_adamson_umap_{}.pdf".format("full" if full_adamson_set else "reduced" ))
plt.show()

# %%
polymerases = ['Polr3a','Pold4','Poln','Polr1c','Pole','Polr3g','Polr3gl','Pole2','Polr2m','Polr2h','Polr2g','Polr1has',
               'Polr2e','Polr3k','Polr2i','Polr3f','Polr1h','Polr1f','Polr1b','Polr2c','Polr2b','Polg2','Pold2','Polb','Pola1',
               'Polr1g','Polr3d','Polq','Polr1a','Polr2j','Pole4','Polr2l','Pold1','Polm','Polr2k','Poll','Polr2a','Polk','Polr2f',
               'Polr1e','Pold3','Polr1d','Polr3b','Polr2d','Polh', 'Polg', 'Poldip3', 'Poldip2', 'Polr3c', 'Pole3','Polrmt','Poli','Pola2','Polr3e','Polr3h']
regex_str = "|".join(polymerases)
u = draw_umap(Xdiff, n_neighbors=10, min_dist=0.1, n_components=2, metric='cosine', 
            title='Polymerases', 
            hue=Xdiff.index.get_level_values("Gene").str.contains(regex_str), hue_order=[True, False], labels=get_labels(Xdiff, polymerases))
plt.savefig("artifacts/Polymerases_adamson_umap_{}.pdf".format("full" if full_adamson_set else "reduced" ))
plt.show()

# %%
u = draw_umap(Xdiff, n_neighbors=10, min_dist=0.1, n_components=2, metric='cosine', 
            title='All genes', labels=Xdiff.index.to_series(), correct_labels=True)
plt.show()
u = draw_umap(Xdiff, n_neighbors=10, min_dist=0.1, n_components=2, metric='cosine', 
            title='All genes', labels=Xdiff.index.to_series(), correct_labels=False)
plt.savefig("artifacts/adamson_umap_{}.pdf".format("full" if full_adamson_set else "reduced" ))
plt.show()
# Out:
# /var/folders/5x/n2td64g918lgvdh3qm2x3bhc0000gn/T/ipykernel_41793/1858796083.py:17: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x= u[:, 0], y= u[:, 1], ax=ax, hue=hue, hue_order=hue_order, palette=palette, alpha=0.5)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /var/folders/5x/n2td64g918lgvdh3qm2x3bhc0000gn/T/ipykernel_41793/1858796083.py:17: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x= u[:, 0], y= u[:, 1], ax=ax, hue=hue, hue_order=hue_order, palette=palette, alpha=0.5)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Psuedo-controls
# - Use psuedo-controls and compare UMAPs to above plots

# %% [markdown]
# # Data Integration
#
# - Load T2 and T3 target data
# - Get difference profiles based on psuedo-controls
# - Combine and visualise above plots again

# %%
Z = pkl.load(open("{}/imputed_adamson_sample_data.pkl".format(get_experiment_artifacts(profile_type=SAMPLE)), "rb"))
Z.update(pkl.load(open("{}/imputed_sample_data.pkl".format(get_experiment_artifacts(profile_type=SAMPLE)), "rb")))


del Z["MB01"]
del Z["MB02"]
# del Z["MB03"]
# del Z["MB04"]
# del Z["MB05"]
# del Z["MB06"]

# del Z["T1"]
# del Z["T2"]
# del Z["T3"]
d_paired = pd.concat(Z, axis=1).dropna()
print(d_paired.shape)
# Out:
# (415, 42)

# %%
Xall = d_paired.stack().stack()\
    .to_frame().reset_index()\
    .rename(columns={"level_2": "Sample", 0: "Value"})\
    .pivot(index=["Sample", "Gene"], columns=["lumc_category"], values="Value")
Xall.head()
# Out:
# lumc_category                                       Any Insertion  \
# Sample                                      Gene
# K562_SpCas9_target-1_HDR_oBA701_AX227_rep_1 Actl6a       0.179460
#                                             Actr5        0.160807
#                                             Actr8        0.144000
#                                             Aicda        0.138997
#                                             Alkbh2       0.140536
#
# lumc_category                                       Deletion 0bp microhomology  \
# Sample                                      Gene
# K562_SpCas9_target-1_HDR_oBA701_AX227_rep_1 Actl6a                    0.176425
#                                             Actr5                     0.181376
#                                             Actr8                     0.190534
#                                             Aicda                     0.184504
# ...

# %%
common_genes = Xall.index.get_level_values(1).to_series()
common_genes = np.intersect1d(adamson_genes, common_genes)

# %%
common_genes.shape
# Out:
# (100,)

# %%
results = {}
pseudo_controls = {}
for alias in Z.keys():
    pca_scores, loadings, explained_variance_ratio, distances, pvalues = logratio_outlier_detection(Z[alias].loc[common_genes], MinCovDet(random_state=0))
    results[alias] = pca_scores, loadings, explained_variance_ratio, distances, pvalues
    results[alias] = pd.Series(distances, index=Z[alias].loc[common_genes].index).sort_values(ascending=False)
    pseudo_controls[alias] = results[alias].iloc[-len(controls):].index.to_series()

# %%
Xpseudodiff = {}
for alias in Z.keys():
    Xpseudodiff[alias] = Xall.loc[Xall.index.get_level_values(0) == alias, :]
    Xpseudodiff[alias] = Xpseudodiff[alias].loc[Xpseudodiff[alias].index.get_level_values(1).isin(common_genes)]
    Xpseudodiff[alias] = calculate_difference_to_controls(Xpseudodiff[alias], pseudo_controls[alias], [alias])
# Out:
# (100, 7)
# (29, 7)
# (100, 7)
# (7,)
# (100, 7)
# (100, 7)
# (29, 7)
# (100, 7)
# (7,)
# (100, 7)
# (100, 7)
# (29, 7)
# (100, 7)
# (7,)
# (100, 7)
# (100, 7)
# (29, 7)
# (100, 7)
# (7,)
# (100, 7)
# (100, 7)
# (29, 7)
# (100, 7)
# (7,)
# (100, 7)
# (100, 7)
# (29, 7)
# (100, 7)
# (7,)
# (100, 7)

# %%
Xpseudodiff = pd.concat(Xpseudodiff.values(), axis=1)

# %%
mapping_target_to_replicate = {
    "Adamson_T1" : ["K562_SpCas9_target-1_HDR_oBA701_AX227_rep_1", "K562_SpCas9_target-1_HDR_oBA701_AX227_rep_2"],
    "T1": ["MB01", "MB02"],
    "T2": ["MB03", "MB04"],
    "T3": ["MB05", "MB06"],
}

# %%
colors = cluster_assignments_df[["Gene", "color", "cluster_assignments"]].reset_index(drop=True).drop_duplicates().set_index("Gene").to_dict()["color"]
in_cluster_genes = cluster_assignments_df.loc[cluster_assignments_df["cluster_assignments"] != -1]["Gene"].unique()

for i in Xpseudodiff.index.to_list():
    if i not in colors:
        colors[i] = (0.7529411764705882, 0.7529411764705882, 0.7529411764705882)

regex_str = "|".join(fanconi)
for alias in ["Adamson_T1", "T2", "T3"]:
    umap_df = Xpseudodiff.loc[:, Xpseudodiff.columns.get_level_values(0).isin(mapping_target_to_replicate[alias])]
    u = draw_umap(umap_df, n_neighbors=15, min_dist=0.1, n_components=2, metric='cosine', hue=Xpseudodiff.index.to_list(),
            palette=colors, legend=False, labels=get_labels(Xpseudodiff, in_cluster_genes), correct_labels=False)
    plt.savefig("artifacts/fanconi_anemia_{}_umap_{}.pdf".format(alias, "full" if full_adamson_set else "reduced" ))
    plt.show()

# %%
regex_str = "|".join(fanconi)
for alias in ["Adamson_T1", "T3"]:
    umap_df = Xpseudodiff.loc[:, Xpseudodiff.columns.get_level_values(0).isin(mapping_target_to_replicate[alias])]
    u = draw_umap(umap_df, n_neighbors=15, min_dist=0.1, n_components=2, metric='cosine', 
            title='Fanconi Anemia', 
            hue=umap_df.index.get_level_values(0).str.contains(regex_str), hue_order=[True, False], labels=get_labels(umap_df, fanconi))
    plt.savefig("artifacts/fanconi_anemia_{}_umap_{}.pdf".format(alias, "full" if full_adamson_set else "reduced" ))
    plt.show()

# %%
regex_str = "|".join(NHEJ)
for alias in ["Adamson_T1", "T3"]:
    umap_df = Xpseudodiff.loc[:, Xpseudodiff.columns.get_level_values(0).isin(mapping_target_to_replicate[alias])]
    u = draw_umap(umap_df, n_neighbors=15, min_dist=0.1, n_components=2, metric='cosine', 
            title='NHEJ', 
            hue=umap_df.index.get_level_values(0).str.contains(regex_str), hue_order=[True, False], labels=get_labels(umap_df, NHEJ))
    plt.savefig("artifacts/NHEJ_{}_umap_{}.pdf".format(alias, "full" if full_adamson_set else "reduced" ))
    plt.show()

# %%
regex_str = "|".join(HR)
for alias in ["Adamson_T1", "T3"]:
    umap_df = Xpseudodiff.loc[:, Xpseudodiff.columns.get_level_values(0).isin(mapping_target_to_replicate[alias])]
    u = draw_umap(umap_df, n_neighbors=15, min_dist=0.1, n_components=2, metric='cosine', 
            title='HR', 
            hue=umap_df.index.get_level_values(0).str.contains(regex_str), hue_order=[True, False], labels=get_labels(umap_df, HR))
    plt.savefig("artifacts/HR_{}_umap_{}.pdf".format(alias, "full" if full_adamson_set else "reduced" ))
    plt.show()

# %%
polymerases = ['Polr3a','Pold4','Poln','Polr1c','Pole','Polr3g','Polr3gl','Pole2','Polr2m','Polr2h','Polr2g','Polr1has',
               'Polr2e','Polr3k','Polr2i','Polr3f','Polr1h','Polr1f','Polr1b','Polr2c','Polr2b','Polg2','Pold2','Polb','Pola1',
               'Polr1g','Polr3d','Polq','Polr1a','Polr2j','Pole4','Polr2l','Pold1','Polm','Polr2k','Poll','Polr2a','Polk','Polr2f',
               'Polr1e','Pold3','Polr1d','Polr3b','Polr2d','Polh', 'Polg', 'Poldip3', 'Poldip2', 'Polr3c', 'Pole3','Polrmt','Poli','Pola2','Polr3e','Polr3h']
regex_str = "|".join(polymerases)
for alias in ["Adamson_T1", "T3"]:
    umap_df = Xpseudodiff.loc[:, Xpseudodiff.columns.get_level_values(0).isin(mapping_target_to_replicate[alias])]
    u = draw_umap(umap_df, n_neighbors=15, min_dist=0.1, n_components=2, metric='cosine', 
            title='Polymerases', 
            hue=umap_df.index.get_level_values(0).str.contains(regex_str), hue_order=[True, False], labels=get_labels(umap_df, polymerases))
    plt.savefig("artifacts/Polymerases_{}_umap_{}.pdf".format(alias, "full" if full_adamson_set else "reduced" ))
    plt.show()

# %%
for alias in ["Adamson_T1", "T3"]:
    umap_df = Xpseudodiff.loc[:, Xpseudodiff.columns.get_level_values(0).isin(mapping_target_to_replicate[alias])]
    u = draw_umap(umap_df, n_neighbors=15, min_dist=0.1, n_components=2, metric='cosine', 
                title='All genes', labels=umap_df.index.to_series(), correct_labels=True)
    plt.show()
    u = draw_umap(umap_df, n_neighbors=15, min_dist=0.1, n_components=2, metric='cosine', 
                title='All genes', labels=umap_df.index.to_series(), correct_labels=False)
    plt.savefig("artifacts/adamson_{}_umap_{}.pdf".format(alias, "full" if full_adamson_set else "reduced" ))
    plt.show()
# Out:
# /var/folders/5x/n2td64g918lgvdh3qm2x3bhc0000gn/T/ipykernel_41793/1858796083.py:17: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x= u[:, 0], y= u[:, 1], ax=ax, hue=hue, hue_order=hue_order, palette=palette, alpha=0.5)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /var/folders/5x/n2td64g918lgvdh3qm2x3bhc0000gn/T/ipykernel_41793/1858796083.py:17: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x= u[:, 0], y= u[:, 1], ax=ax, hue=hue, hue_order=hue_order, palette=palette, alpha=0.5)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
for alias in ["Adamson_T1"]:
    umap_df = Xpseudodiff.loc[:, Xpseudodiff.columns.get_level_values(0).isin(mapping_target_to_replicate[alias])]
    u = draw_umap(umap_df, n_neighbors=15, min_dist=0.1, n_components=2, metric='cosine', 
                title='All genes', labels=get_labels(umap_df, ["Mlh1", "Msh2", "Msh6", "Pms2", "Exo1"]), correct_labels=True)
    plt.show()
# Out:
# /var/folders/5x/n2td64g918lgvdh3qm2x3bhc0000gn/T/ipykernel_41793/1858796083.py:17: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x= u[:, 0], y= u[:, 1], ax=ax, hue=hue, hue_order=hue_order, palette=palette, alpha=0.5)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
